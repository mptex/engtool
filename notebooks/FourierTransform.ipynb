# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m
from scipy import signal
x = np.linspace(1, 2,1000)
y =  signal.square(2*np.pi*1*x)

fig = plt.subplot()
plt.style.use('ggplot')
fig.plot(x,y)

# %%
from scipy.fft import fft, ifft
def squareWave(w):
    y_f = 0
    for t in range(w):
     y_f += (4/np.pi)*(1/(2*t+1))*np.sin(2*np.pi*(2*t+1)*x)
    return y_f

fig1, fig = plt.subplots()

color = 'tab:red'
fig.set_xlabel('time (s)')
fig.set_ylabel('Original Signal')
fig.plot(x, squareWave(10))#, x, fft(x))
fig.tick_params(axis='y')
print(np.sum(x))
plt.show()
# Out:
# 1500.0
